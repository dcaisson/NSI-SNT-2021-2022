# %%
# Premier graphique
import matplotlib.pyplot as plt

annees = [2017, 2018, 2019, 2020, 2021, 2022]
volume = [122, 156, 201, 254, 319, 396]
plt.bar(annees, volume, width=0.5, color="lightblue")
plt.grid(axis="y")
plt.title("Volume mensuel de trafic sur Internet en exaoctets par mois")
#plt.xlabel("Années")
plt.ylabel("Volume mensuel en exaoctets")
plt.text(2016.83, 125,"122")
plt.text(2017.83, 159, "156")
plt.text(2018.83, 204, "201")
plt.text(2019.83, 257, "254")
plt.text(2020.83, 322, "319")
plt.text(2021.83, 399, "396")
plt.show()

# %%
# Deuxième graphique
import matplotlib.pyplot as plt

reseaux = ["Facebook", "YouTube", "Whatsapp", "Instagram", "Twitter", "Snapchat"]
utilisateurs = [2234, 1900, 1500, 1000, 335, 291]
plt.bar(reseaux, utilisateurs, width=0.5, color="lightblue")
plt.grid(axis="y")
plt.title("Nombre d'utilisateurs actifs par mois de quelques réseaux sociaux (2019)")
plt.ylabel("Nombre d'utilisateurs actifs en millions")
plt.show()
